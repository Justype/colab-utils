# %%
#@markdown # <img src="https://help.connected.illumina.com/~gitbook/image?url=https%3A%2F%2F3156063604-files.gitbook.io%2F%7E%2Ffiles%2Fv0%2Fb%2Fgitbook-x-prod.appspot.com%2Fo%2Fspaces%252FPmoo86VVXtTJ9YEMo0gk%252Fuploads%252Fgit-blob-63feffd3eee8a0d0d7a7c21485e8a9076b2c57e1%252FCompression-logo.png%3Falt%3Dmedia&width=300&dpr=1&quality=100&sign=dd5e21aa&sv=2" alt="Dragen Logo" width="50"/> Downloading Dragen Decompression

#@markdown ## Make sure your `.fastq.ora` files on the left.
# !echo "Downloading Dragen Decompression"
# !wget -q -N https://s3.amazonaws.com/webdata.illumina.com/downloads/software/dragen-decompression/orad.2.7.0.linux.tar.gz
# !echo "Extracting Dragen Decompression to orad"
# !tar xf ./orad.2.7.0.linux.tar.gz
# !mv ./orad.2.7.0.linux ./orad
# !mkdir -p ./input
# !echo "Done"

# %%
#@markdown # Run this chunk to decompress files
#@markdown # 🤐 ➡️ 😊
#@markdown ## OUTPUT FILE: `output.tar` (all the `fastq.gz` files are in this)

# !mkdir -p ./output
# !ls *.fastq.ora | xargs -I {} \
  orad/orad {} \
  --path output\
  --ora-reference orad/oradata/
# !tar cf ./output.tar ./output
# Out:
# Orad version  2.7.0-c9253
# [Decompressing file]  100.0%
# decompressed ora file to output/NFE_TwistRefSeq_RowE_10_S10_L001_R1_001.fastq.gz

# %% [markdown]
# ![image.png](data:image/png;base64,...)
